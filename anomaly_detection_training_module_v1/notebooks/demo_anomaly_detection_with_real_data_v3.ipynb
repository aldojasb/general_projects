# %% [markdown]
# # Applying the MVP code into real data

# %%
from pathlib import Path
from anomaly_detection.get_raw_data import get_raw_data
from anomaly_detection.helpers import (
    get_postgre_credentials_and_string_from_env_variables,
    save_dictionary_of_dataframes_to_parquet,
    load_and_process_params,
    adjusting_the_name_of_the_variable_of_interest,
    save_dataframes_to_parquet,
    save_model,
    get_month_year_string,
)
from anomaly_detection.process_data import (
    slice_dataframe_by_date,
    normalize_data,
    combine_ro_dataframes_into_single_dataframe,
    combine_and_slice_plost_to_support_final_analyses,
)
from anomaly_detection.evaluate import (
    overlay_plots_with_holoviews,
    reconstructed_error_analysis_plot_with_holoviews,
)

from anomaly_detection.train import (
    find_best_window_size,
    train_the_model_with_opt_parameters,
    calculate_mean_reconstruction_error_for_a_given_window_size,
    objective,
    train_the_model_with_optimized_hyperparameters,
)

from anomaly_detection.predict import detect_anomalies_using_trained_model
import pandas as pd
import datetime

from typing import (
    NewType,
)
import optuna
from optuna.trial import TrialState
from datetime import datetime, timezone
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

Col = NewType("Col", str)
Table = NewType("Table", str)
Param = NewType("Param", str)
ParamMap = NewType("ParamMap", dict[Param, tuple[Table, Col]])
Query = NewType("Query", str)
Train = str
Filename = str

pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 100)
pd.set_option("display.min_rows", 100)
pd.set_option("display.expand_frame_repr", True)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b7c7673b-fab9-4190-bb6b-bf1f1a490060" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"23f8c5b8-36ba-403d-98ff-71d78fb39631":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"62340c2cb2534bb6a2f4484b4489b1ab","client_comm_id":"d4056924dac74f1592e290db796e95e5"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"23f8c5b8-36ba-403d-98ff-71d78fb39631","roots":{"p1002":"b7c7673b-fab9-4190-bb6b-bf1f1a490060"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# ## 1- read the parameters (json file)

# %%
# Example of how to call the function and use the results
file_path = "parameters_for_real_data_experiments_v2.json"  # Path to your JSON file
(
    train_param_map,
    common_param_map,
    train_format_args,
    variable_of_interest,
    tolerance_for_anomaly,
    train_name,
    start_timestamp,
    end_timestamp,
    start_timestamp_for_training,
    end_timestamp_for_training,
    path_to_save_the_outcomes,
    number_of_chunks,
    num_of_layers,
    window_sizes,
    num_of_epoches,
    lr,
) = load_and_process_params(file_path)
# Out:
# 2024-07-30 18:57:09 - INFO - Train Parameter Map:
# 2024-07-30 18:57:09 - INFO - permeate_flow: Table -> raw_ro{X}_data, Column -> RO_3{Y}_FIT_6{X}1_outPV_Actual
# 2024-07-30 18:57:09 - INFO - silica_saturation_index: Table -> ai_sbro_optout, Column -> ROi_Train_{X}_sat_sio2_index
# 2024-07-30 18:57:09 - INFO - calcium_fluoride_saturation_index: Table -> ai_sbro_optout, Column -> ROi_Train_{X}_sat_caf2_index
# 2024-07-30 18:57:09 - INFO - feed_flow: Table -> raw_rofeed_data, Column -> PMP_6{X}1_FIT_{X}11_outPV_Actual
# 2024-07-30 18:57:09 - INFO - permeate_conductivity: Table -> raw_romain_data, Column -> RO_3{Y}_AIT_6{X}1_outPV_Actual
# 2024-07-30 18:57:09 - INFO - Common Parameter Map:
# 2024-07-30 18:57:09 - INFO - feed_ph_1: Table -> raw_romain_data, Column -> FLTR_601_AIT_01_outPV_Actual
# 2024-07-30 18:57:09 - INFO - feed_silica: Table -> raw_romain_data, Column -> FLTR_601_AIT_006_outPV_Actual
# 2024-07-30 18:57:09 - INFO - feed_calcium: Table -> raw_romain_data, Column -> FLTR_601_AIT_008_outPV_Actual
# 2024-07-30 18:57:09 - INFO - feed_temperature: Table -> raw_in_data, Column -> TK_306_TIT_002_outPV_Actual
# 2024-07-30 18:57:09 - INFO - feed_orp_1: Table -> ai_acf_inp, Column -> RO_feed_orp_1
# 2024-07-30 18:57:09 - INFO - train format args:
# 2024-07-30 18:57:09 - INFO - {'RO1': {'X': 1, 'Y': 66}}
# 2024-07-30 18:57:09 - INFO - num_of_layers:
# 2024-07-30 18:57:09 - INFO - [1, 3]
# 2024-07-30 18:57:09 - INFO - window_sizes:
# 2024-07-30 18:57:09 - INFO - [1, 100]
# 2024-07-30 18:57:09 - INFO - num_of_epochs:
# 2024-07-30 18:57:09 - INFO - [300, 900]
# 2024-07-30 18:57:09 - INFO - learning_rate:
# 2024-07-30 18:57:09 - INFO - [1e-05, 0.1]
# 2024-07-30 18:57:09 - INFO - variable_of_interest:
# 2024-07-30 18:57:09 - INFO - permeate_conductivity
# 2024-07-30 18:57:09 - INFO - tolerance_for_anomaly:
# 2024-07-30 18:57:09 - INFO - 19.0
# 2024-07-30 18:57:09 - INFO - train name:
# 2024-07-30 18:57:09 - INFO - RO1
# 2024-07-30 18:57:09 - INFO - timesetmp for extracting data:
# 2024-07-30 18:57:09 - INFO - from 2024-01-01 00:00:00+00:00 to 2024-01-31 23:59:59+00:00
# 2024-07-30 18:57:09 - INFO - timesetmp for training:
# 2024-07-30 18:57:09 - INFO - from 2024-01-22 00:00:00+00:00 to 2024-01-23 23:59:59+00:00
# 2024-07-30 18:57:09 - INFO - path to save the outcomes
# 2024-07-30 18:57:09 - INFO - /workspace/synauta-ml-ds/projects/turing_ds_anomaly_detection_mvp/exploration
# 2024-07-30 18:57:09 - INFO - number of chunks to split the evaluation plots
# 2024-07-30 18:57:09 - INFO - 3

# %% [markdown]
# ### adjust the variable_of_interest name

# %%
variable_of_interest = adjusting_the_name_of_the_variable_of_interest(
    variable_of_interest=variable_of_interest,
    train_param_map=train_param_map,
    train_name=train_name,
)

# %% [markdown]
# ### creating a time-stamp for this experiment

# %%
# Generate current timestamp
timestamp_for_this_experiment = datetime.now().strftime("%Y%m%d_%H%M%S")

# %% [markdown]
# ## 2- download data to train and test the model

# %% [markdown]
# Remember to properly set the credentials to access Icarus on your env:

# %%
(
    credentials_dict,
    credentials_string,
) = get_postgre_credentials_and_string_from_env_variables()

# %%
data = get_raw_data(
    start_date=start_timestamp,
    end_date=end_timestamp,
    postgres_dsn_string=credentials_string,
    train_param_map=train_param_map,
    common_param_map=common_param_map,
    train_format_args=train_format_args,
)
# Out:
# 2024-07-30 18:57:09 - INFO - Using the following datetime range to filter data within postgreSQL: from 2024-01-01 00:00:00+00:00 to 2024-01-31 23:59:59+00:00
# 2024-07-30 18:57:09 - INFO - Connecting to the database using the postgre string
# 2024-07-30 18:57:10 - INFO - Querying database table [1/6]
# 2024-07-30 18:57:20 - INFO - Finished querying database table [1/6]
# 2024-07-30 18:57:20 - INFO - Querying database table [2/6]
# 2024-07-30 18:57:20 - INFO - Finished querying database table [2/6]
# 2024-07-30 18:57:20 - INFO - Querying database table [3/6]
# 2024-07-30 18:57:30 - INFO - Finished querying database table [3/6]
# 2024-07-30 18:57:30 - INFO - Querying database table [4/6]
# 2024-07-30 18:57:44 - INFO - Finished querying database table [4/6]
# 2024-07-30 18:57:44 - INFO - Querying database table [5/6]
# 2024-07-30 18:57:54 - INFO - Finished querying database table [5/6]
# 2024-07-30 18:57:54 - INFO - Querying database table [6/6]
# 2024-07-30 18:58:04 - INFO - Finished querying database table [6/6]
# 2024-07-30 18:58:04 - INFO - Finished reading data from database
# 2024-07-30 18:58:04 - INFO - reindexing all parameters and tables from postgre
# 2024-07-30 18:58:05 - INFO - merging all parameters and tables from postgre
# 2024-07-30 18:58:05 - INFO - Processing dataframe for train RO1 to remove empty rows and rename the columns/parameters
# 2024-07-30 18:58:05 - INFO - Adding processed dataframe for train RO1 to the dictionary

# %% [markdown]
# ### saving data for future reference

# %%
variable_names = list(data.keys())
base_path = f"{path_to_save_the_outcomes}/tmp/data/{variable_of_interest}/"
month_year_string = get_month_year_string(start_timestamp)

save_dictionary_of_dataframes_to_parquet(
    data=data,
    variable_names=variable_names,
    base_path=base_path,
    specific_suffix=month_year_string,
    time_stemp=timestamp_for_this_experiment,
)
# Out:
# 2024-07-30 18:58:05 - INFO - Saved /workspace/synauta-ml-ds/projects/turing_ds_anomaly_detection_mvp/exploration/tmp/data/RO1_permeate_conductivity/df_ro1_january_2024_20240730_185709.parquet

# %% [markdown]
# # Step 3: train and test the model for train 1

# %% [markdown]
# ### merging all the trains

# %%
# define the train parameters

list_of_train_paramenters = list(train_param_map.keys())

combined_df_with_all_trains_info = combine_ro_dataframes_into_single_dataframe(
    df_dict=data, list_of_train_parameters=list_of_train_paramenters
)

# %% [markdown]
# ### select the data that is stable/normal

# %%
data_to_train = slice_dataframe_by_date(
    df=combined_df_with_all_trains_info,
    start_date=start_timestamp_for_training,
    end_date=end_timestamp_for_training,
)

# %%
base_path = f"{path_to_save_the_outcomes}/tmp/normal_data_to_train_the_model/{variable_of_interest}/{timestamp_for_this_experiment}/training_data/"
specific_suffix = f"{variable_of_interest}_jan_2024"

save_dataframes_to_parquet(
    data_frame=data_to_train,
    base_path=base_path,
    specific_suffix=specific_suffix,
)
# Out:
# 2024-07-30 18:58:05 - INFO - Saved DataFrame to /workspace/synauta-ml-ds/projects/turing_ds_anomaly_detection_mvp/exploration/tmp/normal_data_to_train_the_model/RO1_permeate_conductivity/20240730_185709/training_data/df_RO1_permeate_conductivity_jan_2024.parquet

# %% [markdown]
# #### visualize the standard/normal snippet of data

# %%
plots_05 = overlay_plots_with_holoviews(
    df=data_to_train,
    save_plot=True,
    save_path=f"{path_to_save_the_outcomes}/tmp/normal_data_to_train_the_model/{variable_of_interest}/{timestamp_for_this_experiment}/overlayed_plots_original_data/",
)

normalized_data_for_plots_2, min_max_values_for_plots_2 = normalize_data(data_to_train)

plots_06 = overlay_plots_with_holoviews(
    df=normalized_data_for_plots_2,
    save_plot=True,
    save_path=f"{path_to_save_the_outcomes}/tmp/normal_data_to_train_the_model/{variable_of_interest}/{timestamp_for_this_experiment}/overlayed_plots_norm_data/",
)

# %% [markdown]
# ## hyperparameters optimization

# %%
# Define Optuna study
study = optuna.create_study(direction="minimize")

# Optimize the objective function
study.optimize(lambda trial: objective(trial, df_to_train=data_to_train,
                                       num_of_layers= num_of_layers,
                                       window_sizes=window_sizes, num_of_epoches=num_of_epoches,
                                       lr=lr
                                       ), n_trials=200)
# Out:
# [I 2024-07-30 18:58:10,287] A new study created in memory with name: no-name-5f427efb-bbbb-4ba6-a063-c5ff1e1a09ea
# 2024-07-30 18:58:10 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 18:58:10 - INFO - Create samples with the specified window size:
# 2024-07-30 18:58:10 - INFO - Build the autoencoder model:
# 2024-07-30 18:58:11 - INFO - Train the model:
# 2024-07-30 18:58:24 - INFO - valuate on validation set:
# 2024-07-30 18:58:24 - INFO - Calculate reconstruction error:
# 2024-07-30 18:58:24 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 18:58:24,629] Trial 0 finished with value: 10.06355094909668 and parameters: {'window_sizes': 95, 'num_of_epochs': 553, 'lr': 0.0010746089481287128, 'num_of_layers': 1}. Best is trial 0 with value: 10.06355094909668.
# 2024-07-30 18:58:24 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 18:58:24 - INFO - Create samples with the specified window size:
# 2024-07-30 18:58:24 - INFO - Build the autoencoder model:
# 2024-07-30 18:58:24 - INFO - Train the model:
# 2024-07-30 18:58:34 - INFO - valuate on validation set:
# 2024-07-30 18:58:34 - INFO - Calculate reconstruction error:
# 2024-07-30 18:58:34 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 18:58:34,807] Trial 1 finished with value: 3.995875835418701 and parameters: {'window_sizes': 12, 'num_of_epochs': 553, 'lr': 0.009285488054835436, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 18:58:34 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 18:58:34 - INFO - Create samples with the specified window size:
# 2024-07-30 18:58:35 - INFO - Build the autoencoder model:
# 2024-07-30 18:58:35 - INFO - Train the model:
# 2024-07-30 18:58:45 - INFO - valuate on validation set:
# 2024-07-30 18:58:45 - INFO - Calculate reconstruction error:
# 2024-07-30 18:58:45 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 18:58:45,128] Trial 2 finished with value: 27.764949798583984 and parameters: {'window_sizes': 2, 'num_of_epochs': 880, 'lr': 0.00251307502132829, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 18:58:45 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 18:58:45 - INFO - Create samples with the specified window size:
# 2024-07-30 18:58:45 - INFO - Build the autoencoder model:
# 2024-07-30 18:58:45 - INFO - Train the model:
# 2024-07-30 18:58:48 - INFO - valuate on validation set:
# 2024-07-30 18:58:48 - INFO - Calculate reconstruction error:
# 2024-07-30 18:58:48 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 18:58:48,861] Trial 3 finished with value: 400.9455871582031 and parameters: {'window_sizes': 7, 'num_of_epochs': 325, 'lr': 0.0002915926823592007, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 18:58:48 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 18:58:48 - INFO - Create samples with the specified window size:
# 2024-07-30 18:58:48 - INFO - Build the autoencoder model:
# 2024-07-30 18:58:48 - INFO - Train the model:
# 2024-07-30 18:59:09 - INFO - valuate on validation set:
# 2024-07-30 18:59:09 - INFO - Calculate reconstruction error:
# 2024-07-30 18:59:09 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 18:59:09,107] Trial 4 finished with value: 6.952968120574951 and parameters: {'window_sizes': 17, 'num_of_epochs': 858, 'lr': 0.0074632515197043505, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 18:59:09 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 18:59:09 - INFO - Create samples with the specified window size:
# 2024-07-30 18:59:09 - INFO - Build the autoencoder model:
# 2024-07-30 18:59:09 - INFO - Train the model:
# 2024-07-30 18:59:28 - INFO - valuate on validation set:
# 2024-07-30 18:59:28 - INFO - Calculate reconstruction error:
# 2024-07-30 18:59:28 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 18:59:28,669] Trial 5 finished with value: 33.202022552490234 and parameters: {'window_sizes': 97, 'num_of_epochs': 623, 'lr': 4.8819612638262184e-05, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 18:59:28 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 18:59:28 - INFO - Create samples with the specified window size:
# 2024-07-30 18:59:28 - INFO - Build the autoencoder model:
# 2024-07-30 18:59:28 - INFO - Train the model:
# 2024-07-30 18:59:38 - INFO - valuate on validation set:
# 2024-07-30 18:59:38 - INFO - Calculate reconstruction error:
# 2024-07-30 18:59:38 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 18:59:38,244] Trial 6 finished with value: 16.621427536010742 and parameters: {'window_sizes': 38, 'num_of_epochs': 759, 'lr': 0.00010188924429177461, 'num_of_layers': 1}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 18:59:38 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 18:59:38 - INFO - Create samples with the specified window size:
# 2024-07-30 18:59:38 - INFO - Build the autoencoder model:
# 2024-07-30 18:59:38 - INFO - Train the model:
# 2024-07-30 18:59:49 - INFO - valuate on validation set:
# 2024-07-30 18:59:49 - INFO - Calculate reconstruction error:
# 2024-07-30 18:59:49 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 18:59:49,637] Trial 7 finished with value: 835.5579223632812 and parameters: {'window_sizes': 10, 'num_of_epochs': 714, 'lr': 3.5043022020348255e-05, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 18:59:49 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 18:59:49 - INFO - Create samples with the specified window size:
# 2024-07-30 18:59:49 - INFO - Build the autoencoder model:
# 2024-07-30 18:59:49 - INFO - Train the model:
# 2024-07-30 19:00:00 - INFO - valuate on validation set:
# 2024-07-30 19:00:00 - INFO - Calculate reconstruction error:
# 2024-07-30 19:00:00 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:00:00,169] Trial 8 pruned.
# 2024-07-30 19:00:00 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:00:00 - INFO - Create samples with the specified window size:
# 2024-07-30 19:00:00 - INFO - Build the autoencoder model:
# 2024-07-30 19:00:00 - INFO - Train the model:
# 2024-07-30 19:00:18 - INFO - valuate on validation set:
# 2024-07-30 19:00:18 - INFO - Calculate reconstruction error:
# 2024-07-30 19:00:18 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:00:18,368] Trial 9 finished with value: 42.779815673828125 and parameters: {'window_sizes': 36, 'num_of_epochs': 864, 'lr': 4.586099482727231e-05, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:00:18 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:00:18 - INFO - Create samples with the specified window size:
# 2024-07-30 19:00:18 - INFO - Build the autoencoder model:
# 2024-07-30 19:00:18 - INFO - Train the model:
# 2024-07-30 19:00:24 - INFO - valuate on validation set:
# 2024-07-30 19:00:24 - INFO - Calculate reconstruction error:
# 2024-07-30 19:00:24 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:00:24,679] Trial 10 finished with value: 3961.365234375 and parameters: {'window_sizes': 70, 'num_of_epochs': 433, 'lr': 0.09525153833607801, 'num_of_layers': 1}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:00:24 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:00:24 - INFO - Create samples with the specified window size:
# 2024-07-30 19:00:24 - INFO - Build the autoencoder model:
# 2024-07-30 19:00:24 - INFO - Train the model:
# 2024-07-30 19:00:35 - INFO - valuate on validation set:
# 2024-07-30 19:00:35 - INFO - Calculate reconstruction error:
# 2024-07-30 19:00:35 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:00:35,930] Trial 11 finished with value: 13.241287231445312 and parameters: {'window_sizes': 29, 'num_of_epochs': 518, 'lr': 0.00873074395468496, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:00:35 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:00:35 - INFO - Create samples with the specified window size:
# 2024-07-30 19:00:35 - INFO - Build the autoencoder model:
# 2024-07-30 19:00:35 - INFO - Train the model:
# 2024-07-30 19:00:55 - INFO - valuate on validation set:
# 2024-07-30 19:00:55 - INFO - Calculate reconstruction error:
# 2024-07-30 19:00:55 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:00:55,311] Trial 12 finished with value: 73.38504791259766 and parameters: {'window_sizes': 62, 'num_of_epochs': 732, 'lr': 0.011084379411486702, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:00:55 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:00:55 - INFO - Create samples with the specified window size:
# 2024-07-30 19:00:55 - INFO - Build the autoencoder model:
# 2024-07-30 19:00:55 - INFO - Train the model:
# 2024-07-30 19:01:02 - INFO - valuate on validation set:
# 2024-07-30 19:01:02 - INFO - Calculate reconstruction error:
# 2024-07-30 19:01:02 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:01:02,317] Trial 13 finished with value: 17.380998611450195 and parameters: {'window_sizes': 26, 'num_of_epochs': 424, 'lr': 0.01428140401185938, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:01:02 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:01:02 - INFO - Create samples with the specified window size:
# 2024-07-30 19:01:02 - INFO - Build the autoencoder model:
# 2024-07-30 19:01:02 - INFO - Train the model:
# 2024-07-30 19:01:19 - INFO - valuate on validation set:
# 2024-07-30 19:01:19 - INFO - Calculate reconstruction error:
# 2024-07-30 19:01:19 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:01:19,548] Trial 14 finished with value: 7.3333210945129395 and parameters: {'window_sizes': 21, 'num_of_epochs': 804, 'lr': 0.002424803236388526, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:01:19 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:01:19 - INFO - Create samples with the specified window size:
# 2024-07-30 19:01:19 - INFO - Build the autoencoder model:
# 2024-07-30 19:01:19 - INFO - Train the model:
# 2024-07-30 19:01:37 - INFO - valuate on validation set:
# 2024-07-30 19:01:37 - INFO - Calculate reconstruction error:
# 2024-07-30 19:01:37 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:01:37,836] Trial 15 finished with value: 131.04824829101562 and parameters: {'window_sizes': 53, 'num_of_epochs': 663, 'lr': 0.023202894683491123, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:01:37 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:01:37 - INFO - Create samples with the specified window size:
# 2024-07-30 19:01:37 - INFO - Build the autoencoder model:
# 2024-07-30 19:01:37 - INFO - Train the model:
# 2024-07-30 19:01:49 - INFO - valuate on validation set:
# 2024-07-30 19:01:49 - INFO - Calculate reconstruction error:
# 2024-07-30 19:01:49 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:01:49,251] Trial 16 finished with value: 7.143702507019043 and parameters: {'window_sizes': 17, 'num_of_epochs': 542, 'lr': 0.005261274261422226, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:01:49 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:01:49 - INFO - Create samples with the specified window size:
# 2024-07-30 19:01:49 - INFO - Build the autoencoder model:
# 2024-07-30 19:01:49 - INFO - Train the model:
# 2024-07-30 19:01:54 - INFO - valuate on validation set:
# 2024-07-30 19:01:54 - INFO - Calculate reconstruction error:
# 2024-07-30 19:01:54 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:01:54,717] Trial 17 finished with value: 11.517705917358398 and parameters: {'window_sizes': 43, 'num_of_epochs': 406, 'lr': 0.00044263755496002987, 'num_of_layers': 1}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:01:54 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:01:54 - INFO - Create samples with the specified window size:
# 2024-07-30 19:01:54 - INFO - Build the autoencoder model:
# 2024-07-30 19:01:54 - INFO - Train the model:
# 2024-07-30 19:02:14 - INFO - valuate on validation set:
# 2024-07-30 19:02:14 - INFO - Calculate reconstruction error:
# 2024-07-30 19:02:14 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:02:14,694] Trial 18 finished with value: 448.2335205078125 and parameters: {'window_sizes': 48, 'num_of_epochs': 813, 'lr': 1.0506055184229015e-05, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:02:14 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:02:14 - INFO - Create samples with the specified window size:
# 2024-07-30 19:02:14 - INFO - Build the autoencoder model:
# 2024-07-30 19:02:14 - INFO - Train the model:
# 2024-07-30 19:02:34 - INFO - valuate on validation set:
# 2024-07-30 19:02:34 - INFO - Calculate reconstruction error:
# 2024-07-30 19:02:34 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:02:34,219] Trial 19 finished with value: 544.3812866210938 and parameters: {'window_sizes': 78, 'num_of_epochs': 678, 'lr': 0.03605109087317697, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:02:34 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:02:34 - INFO - Create samples with the specified window size:
# 2024-07-30 19:02:36 - INFO - Build the autoencoder model:
# 2024-07-30 19:02:36 - INFO - Train the model:
# 2024-07-30 19:02:40 - INFO - valuate on validation set:
# 2024-07-30 19:02:40 - INFO - Calculate reconstruction error:
# 2024-07-30 19:02:40 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:02:40,822] Trial 20 finished with value: 3722.5556640625 and parameters: {'window_sizes': 1, 'num_of_epochs': 572, 'lr': 0.0029482864739532825, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:02:40 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:02:40 - INFO - Create samples with the specified window size:
# 2024-07-30 19:02:40 - INFO - Build the autoencoder model:
# 2024-07-30 19:02:40 - INFO - Train the model:
# 2024-07-30 19:02:52 - INFO - valuate on validation set:
# 2024-07-30 19:02:52 - INFO - Calculate reconstruction error:
# 2024-07-30 19:02:52 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:02:52,453] Trial 21 finished with value: 8.464666366577148 and parameters: {'window_sizes': 21, 'num_of_epochs': 494, 'lr': 0.005102533511293633, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:02:52 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:02:52 - INFO - Create samples with the specified window size:
# 2024-07-30 19:02:52 - INFO - Build the autoencoder model:
# 2024-07-30 19:02:52 - INFO - Train the model:
# 2024-07-30 19:03:00 - INFO - valuate on validation set:
# 2024-07-30 19:03:00 - INFO - Calculate reconstruction error:
# 2024-07-30 19:03:00 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:03:00,985] Trial 22 finished with value: 6.482397556304932 and parameters: {'window_sizes': 17, 'num_of_epochs': 487, 'lr': 0.0009679117344042281, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:03:00 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:03:00 - INFO - Create samples with the specified window size:
# 2024-07-30 19:03:01 - INFO - Build the autoencoder model:
# 2024-07-30 19:03:01 - INFO - Train the model:
# 2024-07-30 19:03:09 - INFO - valuate on validation set:
# 2024-07-30 19:03:09 - INFO - Calculate reconstruction error:
# 2024-07-30 19:03:09 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:03:09,438] Trial 23 finished with value: 10.96711540222168 and parameters: {'window_sizes': 32, 'num_of_epochs': 464, 'lr': 0.0009105333412391176, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:03:09 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:03:09 - INFO - Create samples with the specified window size:
# 2024-07-30 19:03:09 - INFO - Build the autoencoder model:
# 2024-07-30 19:03:09 - INFO - Train the model:
# 2024-07-30 19:03:13 - INFO - valuate on validation set:
# 2024-07-30 19:03:13 - INFO - Calculate reconstruction error:
# 2024-07-30 19:03:13 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:03:13,092] Trial 24 finished with value: 16.62353515625 and parameters: {'window_sizes': 15, 'num_of_epochs': 307, 'lr': 0.0007933920695205693, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:03:13 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:03:13 - INFO - Create samples with the specified window size:
# 2024-07-30 19:03:13 - INFO - Build the autoencoder model:
# 2024-07-30 19:03:13 - INFO - Train the model:
# 2024-07-30 19:03:18 - INFO - valuate on validation set:
# 2024-07-30 19:03:18 - INFO - Calculate reconstruction error:
# 2024-07-30 19:03:18 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:03:18,013] Trial 25 finished with value: 538.7883911132812 and parameters: {'window_sizes': 25, 'num_of_epochs': 382, 'lr': 0.02789476333383991, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:03:18 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:03:18 - INFO - Create samples with the specified window size:
# 2024-07-30 19:03:18 - INFO - Build the autoencoder model:
# 2024-07-30 19:03:18 - INFO - Train the model:
# 2024-07-30 19:03:26 - INFO - valuate on validation set:
# 2024-07-30 19:03:26 - INFO - Calculate reconstruction error:
# 2024-07-30 19:03:26 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:03:26,664] Trial 26 finished with value: 8.723662376403809 and parameters: {'window_sizes': 15, 'num_of_epochs': 486, 'lr': 0.0016779077371105167, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:03:26 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:03:26 - INFO - Create samples with the specified window size:
# 2024-07-30 19:03:26 - INFO - Build the autoencoder model:
# 2024-07-30 19:03:26 - INFO - Train the model:
# 2024-07-30 19:03:37 - INFO - valuate on validation set:
# 2024-07-30 19:03:37 - INFO - Calculate reconstruction error:
# 2024-07-30 19:03:37 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:03:37,521] Trial 27 finished with value: 41.1370849609375 and parameters: {'window_sizes': 8, 'num_of_epochs': 581, 'lr': 0.00024239747946929577, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:03:37 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:03:37 - INFO - Create samples with the specified window size:
# 2024-07-30 19:03:37 - INFO - Build the autoencoder model:
# 2024-07-30 19:03:37 - INFO - Train the model:
# 2024-07-30 19:03:44 - INFO - valuate on validation set:
# 2024-07-30 19:03:44 - INFO - Calculate reconstruction error:
# 2024-07-30 19:03:44 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:03:44,403] Trial 28 finished with value: 16.65062141418457 and parameters: {'window_sizes': 42, 'num_of_epochs': 364, 'lr': 0.005987920833690907, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:03:44 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:03:44 - INFO - Create samples with the specified window size:
# 2024-07-30 19:03:44 - INFO - Build the autoencoder model:
# 2024-07-30 19:03:44 - INFO - Train the model:
# 2024-07-30 19:03:53 - INFO - valuate on validation set:
# 2024-07-30 19:03:53 - INFO - Calculate reconstruction error:
# 2024-07-30 19:03:53 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:03:53,406] Trial 29 finished with value: 8.25743293762207 and parameters: {'window_sizes': 82, 'num_of_epochs': 521, 'lr': 0.0012973088614823376, 'num_of_layers': 1}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:03:53 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:03:53 - INFO - Create samples with the specified window size:
# 2024-07-30 19:03:53 - INFO - Build the autoencoder model:
# 2024-07-30 19:03:53 - INFO - Train the model:
# 2024-07-30 19:04:05 - INFO - valuate on validation set:
# 2024-07-30 19:04:05 - INFO - Calculate reconstruction error:
# 2024-07-30 19:04:05 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:04:05,185] Trial 30 finished with value: 15.932295799255371 and parameters: {'window_sizes': 57, 'num_of_epochs': 613, 'lr': 0.004006097097086147, 'num_of_layers': 2}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:04:05 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:04:05 - INFO - Create samples with the specified window size:
# 2024-07-30 19:04:05 - INFO - Build the autoencoder model:
# 2024-07-30 19:04:05 - INFO - Train the model:
# 2024-07-30 19:04:17 - INFO - valuate on validation set:
# 2024-07-30 19:04:17 - INFO - Calculate reconstruction error:
# 2024-07-30 19:04:17 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:04:17,775] Trial 31 finished with value: 14.540426254272461 and parameters: {'window_sizes': 18, 'num_of_epochs': 537, 'lr': 0.014694609441063773, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:04:17 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:04:17 - INFO - Create samples with the specified window size:
# 2024-07-30 19:04:19 - INFO - Build the autoencoder model:
# 2024-07-30 19:04:19 - INFO - Train the model:
# 2024-07-30 19:04:24 - INFO - valuate on validation set:
# 2024-07-30 19:04:24 - INFO - Calculate reconstruction error:
# 2024-07-30 19:04:24 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:04:24,728] Trial 32 finished with value: 2166.91943359375 and parameters: {'window_sizes': 1, 'num_of_epochs': 554, 'lr': 0.008133603694144216, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:04:24 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:04:24 - INFO - Create samples with the specified window size:
# 2024-07-30 19:04:24 - INFO - Build the autoencoder model:
# 2024-07-30 19:04:24 - INFO - Train the model:
# 2024-07-30 19:04:40 - INFO - valuate on validation set:
# 2024-07-30 19:04:40 - INFO - Calculate reconstruction error:
# 2024-07-30 19:04:40 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:04:40,450] Trial 33 finished with value: 10.474471092224121 and parameters: {'window_sizes': 32, 'num_of_epochs': 660, 'lr': 0.0006161808808333828, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:04:40 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:04:40 - INFO - Create samples with the specified window size:
# 2024-07-30 19:04:40 - INFO - Build the autoencoder model:
# 2024-07-30 19:04:40 - INFO - Train the model:
# 2024-07-30 19:04:46 - INFO - valuate on validation set:
# 2024-07-30 19:04:46 - INFO - Calculate reconstruction error:
# 2024-07-30 19:04:46 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:04:46,955] Trial 34 finished with value: 433.6217956542969 and parameters: {'window_sizes': 6, 'num_of_epochs': 459, 'lr': 0.001968326159009609, 'num_of_layers': 3}. Best is trial 1 with value: 3.995875835418701.
# 2024-07-30 19:04:46 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:04:46 - INFO - Create samples with the specified window size:
# 2024-07-30 19:04:47 - INFO - Build the autoencoder model:
# 2024-07-30 19:04:47 - INFO - Train the model:
# 2024-07-30 19:05:00 - INFO - valuate on validation set:
# 2024-07-30 19:05:00 - INFO - Calculate reconstruction error:
# 2024-07-30 19:05:00 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:05:00,112] Trial 35 finished with value: 3.748948812484741 and parameters: {'window_sizes': 22, 'num_of_epochs': 897, 'lr': 0.004369251825986098, 'num_of_layers': 2}. Best is trial 35 with value: 3.748948812484741.
# 2024-07-30 19:05:00 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:05:00 - INFO - Create samples with the specified window size:
# 2024-07-30 19:05:00 - INFO - Build the autoencoder model:
# 2024-07-30 19:05:00 - INFO - Train the model:
# 2024-07-30 19:05:14 - INFO - valuate on validation set:
# 2024-07-30 19:05:14 - INFO - Calculate reconstruction error:
# 2024-07-30 19:05:14 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:05:14,768] Trial 36 finished with value: 7.3215765953063965 and parameters: {'window_sizes': 24, 'num_of_epochs': 892, 'lr': 0.00018266211664401, 'num_of_layers': 2}. Best is trial 35 with value: 3.748948812484741.
# 2024-07-30 19:05:14 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:05:14 - INFO - Create samples with the specified window size:
# 2024-07-30 19:05:15 - INFO - Build the autoencoder model:
# 2024-07-30 19:05:15 - INFO - Train the model:
# 2024-07-30 19:05:24 - INFO - valuate on validation set:
# 2024-07-30 19:05:24 - INFO - Calculate reconstruction error:
# 2024-07-30 19:05:24 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:05:24,016] Trial 37 finished with value: 13.495396614074707 and parameters: {'window_sizes': 10, 'num_of_epochs': 831, 'lr': 0.018821064253873553, 'num_of_layers': 2}. Best is trial 35 with value: 3.748948812484741.
# 2024-07-30 19:05:24 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:05:24 - INFO - Create samples with the specified window size:
# 2024-07-30 19:05:24 - INFO - Build the autoencoder model:
# 2024-07-30 19:05:24 - INFO - Train the model:
# 2024-07-30 19:05:32 - INFO - valuate on validation set:
# 2024-07-30 19:05:32 - INFO - Calculate reconstruction error:
# 2024-07-30 19:05:32 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:05:32,096] Trial 38 finished with value: 529.2103881835938 and parameters: {'window_sizes': 13, 'num_of_epochs': 855, 'lr': 0.04344413435013113, 'num_of_layers': 2}. Best is trial 35 with value: 3.748948812484741.
# 2024-07-30 19:05:32 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:05:32 - INFO - Create samples with the specified window size:
# 2024-07-30 19:05:32 - INFO - Build the autoencoder model:
# 2024-07-30 19:05:32 - INFO - Train the model:
# 2024-07-30 19:05:38 - INFO - valuate on validation set:
# 2024-07-30 19:05:38 - INFO - Calculate reconstruction error:
# 2024-07-30 19:05:38 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:05:38,858] Trial 39 finished with value: 2.2875399589538574 and parameters: {'window_sizes': 6, 'num_of_epochs': 785, 'lr': 0.003939913750315926, 'num_of_layers': 2}. Best is trial 39 with value: 2.2875399589538574.
# 2024-07-30 19:05:38 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:05:38 - INFO - Create samples with the specified window size:
# 2024-07-30 19:05:39 - INFO - Build the autoencoder model:
# 2024-07-30 19:05:39 - INFO - Train the model:
# 2024-07-30 19:05:47 - INFO - valuate on validation set:
# 2024-07-30 19:05:47 - INFO - Calculate reconstruction error:
# 2024-07-30 19:05:47 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:05:47,224] Trial 40 finished with value: 2.830416202545166 and parameters: {'window_sizes': 4, 'num_of_epochs': 771, 'lr': 0.00340787954662542, 'num_of_layers': 2}. Best is trial 39 with value: 2.2875399589538574.
# 2024-07-30 19:05:47 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:05:47 - INFO - Create samples with the specified window size:
# 2024-07-30 19:05:47 - INFO - Build the autoencoder model:
# 2024-07-30 19:05:47 - INFO - Train the model:
# 2024-07-30 19:05:56 - INFO - valuate on validation set:
# 2024-07-30 19:05:56 - INFO - Calculate reconstruction error:
# 2024-07-30 19:05:56 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:05:56,400] Trial 41 finished with value: 27.75067138671875 and parameters: {'window_sizes': 5, 'num_of_epochs': 748, 'lr': 0.002589305172198866, 'num_of_layers': 2}. Best is trial 39 with value: 2.2875399589538574.
# 2024-07-30 19:05:56 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:05:56 - INFO - Create samples with the specified window size:
# 2024-07-30 19:05:56 - INFO - Build the autoencoder model:
# 2024-07-30 19:05:56 - INFO - Train the model:
# 2024-07-30 19:06:10 - INFO - valuate on validation set:
# 2024-07-30 19:06:10 - INFO - Calculate reconstruction error:
# 2024-07-30 19:06:10 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:06:10,068] Trial 42 finished with value: 2.4364569187164307 and parameters: {'window_sizes': 5, 'num_of_epochs': 762, 'lr': 0.0036601206073856043, 'num_of_layers': 2}. Best is trial 39 with value: 2.2875399589538574.
# 2024-07-30 19:06:10 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:06:10 - INFO - Create samples with the specified window size:
# 2024-07-30 19:06:10 - INFO - Build the autoencoder model:
# 2024-07-30 19:06:10 - INFO - Train the model:
# 2024-07-30 19:06:19 - INFO - valuate on validation set:
# 2024-07-30 19:06:19 - INFO - Calculate reconstruction error:
# 2024-07-30 19:06:19 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:06:19,032] Trial 43 finished with value: 2.9934568405151367 and parameters: {'window_sizes': 5, 'num_of_epochs': 784, 'lr': 0.0038801818220434766, 'num_of_layers': 2}. Best is trial 39 with value: 2.2875399589538574.
# 2024-07-30 19:06:19 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:06:19 - INFO - Create samples with the specified window size:
# 2024-07-30 19:06:19 - INFO - Build the autoencoder model:
# 2024-07-30 19:06:19 - INFO - Train the model:
# 2024-07-30 19:06:27 - INFO - valuate on validation set:
# 2024-07-30 19:06:27 - INFO - Calculate reconstruction error:
# 2024-07-30 19:06:27 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:06:27,703] Trial 44 finished with value: 2.446765661239624 and parameters: {'window_sizes': 6, 'num_of_epochs': 780, 'lr': 0.003188516379545585, 'num_of_layers': 2}. Best is trial 39 with value: 2.2875399589538574.
# 2024-07-30 19:06:27 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:06:27 - INFO - Create samples with the specified window size:
# 2024-07-30 19:06:28 - INFO - Build the autoencoder model:
# 2024-07-30 19:06:28 - INFO - Train the model:
# 2024-07-30 19:06:37 - INFO - valuate on validation set:
# 2024-07-30 19:06:37 - INFO - Calculate reconstruction error:
# 2024-07-30 19:06:37 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:06:37,793] Trial 45 finished with value: 25.935791015625 and parameters: {'window_sizes': 3, 'num_of_epochs': 781, 'lr': 0.0014683630005756217, 'num_of_layers': 2}. Best is trial 39 with value: 2.2875399589538574.
# 2024-07-30 19:06:37 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:06:37 - INFO - Create samples with the specified window size:
# 2024-07-30 19:06:38 - INFO - Build the autoencoder model:
# 2024-07-30 19:06:38 - INFO - Train the model:
# 2024-07-30 19:06:48 - INFO - valuate on validation set:
# 2024-07-30 19:06:48 - INFO - Calculate reconstruction error:
# 2024-07-30 19:06:48 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:06:48,112] Trial 46 finished with value: 3.070788860321045 and parameters: {'window_sizes': 10, 'num_of_epochs': 707, 'lr': 0.003613732767956929, 'num_of_layers': 2}. Best is trial 39 with value: 2.2875399589538574.
# 2024-07-30 19:06:48 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:06:48 - INFO - Create samples with the specified window size:
# 2024-07-30 19:06:48 - INFO - Build the autoencoder model:
# 2024-07-30 19:06:48 - INFO - Train the model:
# 2024-07-30 19:06:56 - INFO - valuate on validation set:
# 2024-07-30 19:06:56 - INFO - Calculate reconstruction error:
# 2024-07-30 19:06:56 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:06:56,407] Trial 47 finished with value: 2.4371025562286377 and parameters: {'window_sizes': 7, 'num_of_epochs': 777, 'lr': 0.010572029156796375, 'num_of_layers': 2}. Best is trial 39 with value: 2.2875399589538574.
# 2024-07-30 19:06:56 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:06:56 - INFO - Create samples with the specified window size:
# 2024-07-30 19:06:56 - INFO - Build the autoencoder model:
# 2024-07-30 19:06:56 - INFO - Train the model:
# 2024-07-30 19:07:02 - INFO - valuate on validation set:
# 2024-07-30 19:07:02 - INFO - Calculate reconstruction error:
# 2024-07-30 19:07:02 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:07:02,088] Trial 48 finished with value: 1.3574447631835938 and parameters: {'window_sizes': 8, 'num_of_epochs': 767, 'lr': 0.00950578098231593, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:07:02 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:07:02 - INFO - Create samples with the specified window size:
# 2024-07-30 19:07:02 - INFO - Build the autoencoder model:
# 2024-07-30 19:07:02 - INFO - Train the model:
# 2024-07-30 19:07:08 - INFO - valuate on validation set:
# 2024-07-30 19:07:08 - INFO - Calculate reconstruction error:
# 2024-07-30 19:07:08 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:07:08,350] Trial 49 finished with value: 3.5899617671966553 and parameters: {'window_sizes': 12, 'num_of_epochs': 698, 'lr': 0.010649295968924444, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:07:08 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:07:08 - INFO - Create samples with the specified window size:
# 2024-07-30 19:07:08 - INFO - Build the autoencoder model:
# 2024-07-30 19:07:08 - INFO - Train the model:
# 2024-07-30 19:07:14 - INFO - valuate on validation set:
# 2024-07-30 19:07:14 - INFO - Calculate reconstruction error:
# 2024-07-30 19:07:14 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:07:14,818] Trial 50 finished with value: 1.4329861402511597 and parameters: {'window_sizes': 8, 'num_of_epochs': 738, 'lr': 0.008062696242662818, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:07:14 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:07:14 - INFO - Create samples with the specified window size:
# 2024-07-30 19:07:14 - INFO - Build the autoencoder model:
# 2024-07-30 19:07:14 - INFO - Train the model:
# 2024-07-30 19:07:21 - INFO - valuate on validation set:
# 2024-07-30 19:07:21 - INFO - Calculate reconstruction error:
# 2024-07-30 19:07:21 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:07:21,550] Trial 51 finished with value: 2.117121458053589 and parameters: {'window_sizes': 10, 'num_of_epochs': 744, 'lr': 0.006480194631625867, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:07:21 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:07:21 - INFO - Create samples with the specified window size:
# 2024-07-30 19:07:21 - INFO - Build the autoencoder model:
# 2024-07-30 19:07:21 - INFO - Train the model:
# 2024-07-30 19:07:28 - INFO - valuate on validation set:
# 2024-07-30 19:07:28 - INFO - Calculate reconstruction error:
# 2024-07-30 19:07:28 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:07:28,187] Trial 52 finished with value: 2.689859390258789 and parameters: {'window_sizes': 9, 'num_of_epochs': 740, 'lr': 0.0077087778221882125, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:07:28 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:07:28 - INFO - Create samples with the specified window size:
# 2024-07-30 19:07:30 - INFO - Build the autoencoder model:
# 2024-07-30 19:07:30 - INFO - Train the model:
# 2024-07-30 19:07:33 - INFO - valuate on validation set:
# 2024-07-30 19:07:33 - INFO - Calculate reconstruction error:
# 2024-07-30 19:07:33 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:07:34,012] Trial 53 finished with value: 435.037841796875 and parameters: {'window_sizes': 1, 'num_of_epochs': 818, 'lr': 0.01454148533873771, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:07:34 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:07:34 - INFO - Create samples with the specified window size:
# 2024-07-30 19:07:34 - INFO - Build the autoencoder model:
# 2024-07-30 19:07:34 - INFO - Train the model:
# 2024-07-30 19:07:40 - INFO - valuate on validation set:
# 2024-07-30 19:07:40 - INFO - Calculate reconstruction error:
# 2024-07-30 19:07:40 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:07:40,495] Trial 54 finished with value: 2.221400737762451 and parameters: {'window_sizes': 19, 'num_of_epochs': 723, 'lr': 0.0061629455157115876, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:07:40 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:07:40 - INFO - Create samples with the specified window size:
# 2024-07-30 19:07:40 - INFO - Build the autoencoder model:
# 2024-07-30 19:07:40 - INFO - Train the model:
# 2024-07-30 19:07:47 - INFO - valuate on validation set:
# 2024-07-30 19:07:47 - INFO - Calculate reconstruction error:
# 2024-07-30 19:07:47 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:07:47,799] Trial 55 finished with value: 2.661397695541382 and parameters: {'window_sizes': 15, 'num_of_epochs': 717, 'lr': 0.00606950447157049, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:07:47 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:07:47 - INFO - Create samples with the specified window size:
# 2024-07-30 19:07:47 - INFO - Build the autoencoder model:
# 2024-07-30 19:07:47 - INFO - Train the model:
# 2024-07-30 19:07:54 - INFO - valuate on validation set:
# 2024-07-30 19:07:54 - INFO - Calculate reconstruction error:
# 2024-07-30 19:07:54 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:07:54,193] Trial 56 finished with value: 4.141947269439697 and parameters: {'window_sizes': 19, 'num_of_epochs': 652, 'lr': 0.021113087294237828, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:07:54 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:07:54 - INFO - Create samples with the specified window size:
# 2024-07-30 19:07:54 - INFO - Build the autoencoder model:
# 2024-07-30 19:07:54 - INFO - Train the model:
# 2024-07-30 19:08:04 - INFO - valuate on validation set:
# 2024-07-30 19:08:04 - INFO - Calculate reconstruction error:
# 2024-07-30 19:08:04 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:08:04,163] Trial 57 finished with value: 3.5671398639678955 and parameters: {'window_sizes': 28, 'num_of_epochs': 848, 'lr': 0.0020877765329435343, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:08:04 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:08:04 - INFO - Create samples with the specified window size:
# 2024-07-30 19:08:04 - INFO - Build the autoencoder model:
# 2024-07-30 19:08:04 - INFO - Train the model:
# 2024-07-30 19:08:17 - INFO - valuate on validation set:
# 2024-07-30 19:08:17 - INFO - Calculate reconstruction error:
# 2024-07-30 19:08:17 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:08:17,655] Trial 58 finished with value: 3874.991455078125 and parameters: {'window_sizes': 93, 'num_of_epochs': 689, 'lr': 0.04904763555975523, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:08:17 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:08:17 - INFO - Create samples with the specified window size:
# 2024-07-30 19:08:17 - INFO - Build the autoencoder model:
# 2024-07-30 19:08:17 - INFO - Train the model:
# 2024-07-30 19:08:22 - INFO - valuate on validation set:
# 2024-07-30 19:08:22 - INFO - Calculate reconstruction error:
# 2024-07-30 19:08:22 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:08:22,985] Trial 59 pruned.
# 2024-07-30 19:08:22 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:08:22 - INFO - Create samples with the specified window size:
# 2024-07-30 19:08:23 - INFO - Build the autoencoder model:
# 2024-07-30 19:08:23 - INFO - Train the model:
# 2024-07-30 19:08:30 - INFO - valuate on validation set:
# 2024-07-30 19:08:30 - INFO - Calculate reconstruction error:
# 2024-07-30 19:08:30 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:08:30,548] Trial 60 finished with value: 2.0403409004211426 and parameters: {'window_sizes': 11, 'num_of_epochs': 754, 'lr': 0.028944967661996602, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:08:30 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:08:30 - INFO - Create samples with the specified window size:
# 2024-07-30 19:08:30 - INFO - Build the autoencoder model:
# 2024-07-30 19:08:30 - INFO - Train the model:
# 2024-07-30 19:08:37 - INFO - valuate on validation set:
# 2024-07-30 19:08:37 - INFO - Calculate reconstruction error:
# 2024-07-30 19:08:37 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:08:37,807] Trial 61 finished with value: 2.0816290378570557 and parameters: {'window_sizes': 12, 'num_of_epochs': 794, 'lr': 0.029046342810797748, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:08:37 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:08:37 - INFO - Create samples with the specified window size:
# 2024-07-30 19:08:37 - INFO - Build the autoencoder model:
# 2024-07-30 19:08:37 - INFO - Train the model:
# 2024-07-30 19:08:46 - INFO - valuate on validation set:
# 2024-07-30 19:08:46 - INFO - Calculate reconstruction error:
# 2024-07-30 19:08:46 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:08:46,705] Trial 62 finished with value: 3.6522138118743896 and parameters: {'window_sizes': 11, 'num_of_epochs': 800, 'lr': 0.027650819305706984, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:08:46 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:08:46 - INFO - Create samples with the specified window size:
# 2024-07-30 19:08:46 - INFO - Build the autoencoder model:
# 2024-07-30 19:08:46 - INFO - Train the model:
# 2024-07-30 19:08:55 - INFO - valuate on validation set:
# 2024-07-30 19:08:55 - INFO - Calculate reconstruction error:
# 2024-07-30 19:08:55 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:08:55,173] Trial 63 finished with value: 2.925011157989502 and parameters: {'window_sizes': 22, 'num_of_epochs': 753, 'lr': 0.014242209474443879, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:08:55 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:08:55 - INFO - Create samples with the specified window size:
# 2024-07-30 19:08:55 - INFO - Build the autoencoder model:
# 2024-07-30 19:08:55 - INFO - Train the model:
# 2024-07-30 19:09:03 - INFO - valuate on validation set:
# 2024-07-30 19:09:03 - INFO - Calculate reconstruction error:
# 2024-07-30 19:09:03 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:09:03,436] Trial 64 finished with value: 2815.1611328125 and parameters: {'window_sizes': 18, 'num_of_epochs': 828, 'lr': 0.033646758939655755, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:09:03 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:09:03 - INFO - Create samples with the specified window size:
# 2024-07-30 19:09:03 - INFO - Build the autoencoder model:
# 2024-07-30 19:09:03 - INFO - Train the model:
# 2024-07-30 19:09:09 - INFO - valuate on validation set:
# 2024-07-30 19:09:09 - INFO - Calculate reconstruction error:
# 2024-07-30 19:09:09 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:09:09,169] Trial 65 finished with value: 2309.607177734375 and parameters: {'window_sizes': 13, 'num_of_epochs': 799, 'lr': 0.06064303732877181, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:09:09 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:09:09 - INFO - Create samples with the specified window size:
# 2024-07-30 19:09:09 - INFO - Build the autoencoder model:
# 2024-07-30 19:09:09 - INFO - Train the model:
# 2024-07-30 19:09:15 - INFO - valuate on validation set:
# 2024-07-30 19:09:15 - INFO - Calculate reconstruction error:
# 2024-07-30 19:09:15 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:09:15,021] Trial 66 finished with value: 2.584689140319824 and parameters: {'window_sizes': 10, 'num_of_epochs': 737, 'lr': 0.0066006139272953524, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:09:15 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:09:15 - INFO - Create samples with the specified window size:
# 2024-07-30 19:09:15 - INFO - Build the autoencoder model:
# 2024-07-30 19:09:15 - INFO - Train the model:
# 2024-07-30 19:09:21 - INFO - valuate on validation set:
# 2024-07-30 19:09:21 - INFO - Calculate reconstruction error:
# 2024-07-30 19:09:21 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:09:21,075] Trial 67 finished with value: 3522.07958984375 and parameters: {'window_sizes': 36, 'num_of_epochs': 641, 'lr': 0.01887012680791954, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:09:21 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:09:21 - INFO - Create samples with the specified window size:
# 2024-07-30 19:09:21 - INFO - Build the autoencoder model:
# 2024-07-30 19:09:21 - INFO - Train the model:
# 2024-07-30 19:09:31 - INFO - valuate on validation set:
# 2024-07-30 19:09:31 - INFO - Calculate reconstruction error:
# 2024-07-30 19:09:31 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:09:31,341] Trial 68 finished with value: 3644.7255859375 and parameters: {'window_sizes': 67, 'num_of_epochs': 837, 'lr': 0.012527256752840008, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:09:31 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:09:31 - INFO - Create samples with the specified window size:
# 2024-07-30 19:09:31 - INFO - Build the autoencoder model:
# 2024-07-30 19:09:31 - INFO - Train the model:
# 2024-07-30 19:09:36 - INFO - valuate on validation set:
# 2024-07-30 19:09:36 - INFO - Calculate reconstruction error:
# 2024-07-30 19:09:36 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:09:36,021] Trial 69 finished with value: 1.8552649021148682 and parameters: {'window_sizes': 20, 'num_of_epochs': 679, 'lr': 0.009323735016841223, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:09:36 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:09:36 - INFO - Create samples with the specified window size:
# 2024-07-30 19:09:36 - INFO - Build the autoencoder model:
# 2024-07-30 19:09:36 - INFO - Train the model:
# 2024-07-30 19:09:42 - INFO - valuate on validation set:
# 2024-07-30 19:09:42 - INFO - Calculate reconstruction error:
# 2024-07-30 19:09:42 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:09:42,075] Trial 70 finished with value: 443.1922912597656 and parameters: {'window_sizes': 30, 'num_of_epochs': 687, 'lr': 0.027137362469371887, 'num_of_layers': 1}. Best is trial 48 with value: 1.3574447631835938.
# 2024-07-30 19:09:42 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:09:42 - INFO - Create samples with the specified window size:
# 2024-07-30 19:09:42 - INFO - Build the autoencoder model:
# 2024-07-30 19:09:42 - INFO - Train the model:
# 2024-07-30 19:09:46 - INFO - valuate on validation set:
# 2024-07-30 19:09:46 - INFO - Calculate reconstruction error:
# ...
# 2024-07-30 19:20:19 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:20:19 - INFO - Create samples with the specified window size:
# 2024-07-30 19:20:20 - INFO - Build the autoencoder model:
# 2024-07-30 19:20:20 - INFO - Train the model:
# 2024-07-30 19:20:26 - INFO - valuate on validation set:
# 2024-07-30 19:20:26 - INFO - Calculate reconstruction error:
# 2024-07-30 19:20:26 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:20:26,497] Trial 173 finished with value: 0.568994402885437 and parameters: {'window_sizes': 3, 'num_of_epochs': 861, 'lr': 0.03777256269175889, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:20:26 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:20:26 - INFO - Create samples with the specified window size:
# 2024-07-30 19:20:26 - INFO - Build the autoencoder model:
# 2024-07-30 19:20:26 - INFO - Train the model:
# 2024-07-30 19:20:32 - INFO - valuate on validation set:
# 2024-07-30 19:20:32 - INFO - Calculate reconstruction error:
# 2024-07-30 19:20:32 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:20:32,992] Trial 174 finished with value: 1.3694841861724854 and parameters: {'window_sizes': 6, 'num_of_epochs': 871, 'lr': 0.039609206887020965, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:20:33 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:20:33 - INFO - Create samples with the specified window size:
# 2024-07-30 19:20:34 - INFO - Build the autoencoder model:
# 2024-07-30 19:20:34 - INFO - Train the model:
# 2024-07-30 19:20:38 - INFO - valuate on validation set:
# 2024-07-30 19:20:38 - INFO - Calculate reconstruction error:
# 2024-07-30 19:20:38 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:20:38,783] Trial 175 pruned.
# 2024-07-30 19:20:38 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:20:38 - INFO - Create samples with the specified window size:
# 2024-07-30 19:20:38 - INFO - Build the autoencoder model:
# 2024-07-30 19:20:38 - INFO - Train the model:
# 2024-07-30 19:20:45 - INFO - valuate on validation set:
# 2024-07-30 19:20:45 - INFO - Calculate reconstruction error:
# 2024-07-30 19:20:45 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:20:45,120] Trial 176 finished with value: 6.717268466949463 and parameters: {'window_sizes': 9, 'num_of_epochs': 827, 'lr': 0.045510885104819127, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:20:45 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:20:45 - INFO - Create samples with the specified window size:
# 2024-07-30 19:20:45 - INFO - Build the autoencoder model:
# 2024-07-30 19:20:45 - INFO - Train the model:
# 2024-07-30 19:20:51 - INFO - valuate on validation set:
# 2024-07-30 19:20:51 - INFO - Calculate reconstruction error:
# 2024-07-30 19:20:51 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:20:51,243] Trial 177 finished with value: 0.9849066734313965 and parameters: {'window_sizes': 4, 'num_of_epochs': 859, 'lr': 0.02604630656136032, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:20:51 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:20:51 - INFO - Create samples with the specified window size:
# 2024-07-30 19:20:51 - INFO - Build the autoencoder model:
# 2024-07-30 19:20:51 - INFO - Train the model:
# 2024-07-30 19:20:56 - INFO - valuate on validation set:
# 2024-07-30 19:20:56 - INFO - Calculate reconstruction error:
# 2024-07-30 19:20:56 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:20:56,178] Trial 178 finished with value: 0.8914251923561096 and parameters: {'window_sizes': 3, 'num_of_epochs': 863, 'lr': 0.037733245252951145, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:20:56 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:20:56 - INFO - Create samples with the specified window size:
# 2024-07-30 19:20:56 - INFO - Build the autoencoder model:
# 2024-07-30 19:20:56 - INFO - Train the model:
# 2024-07-30 19:21:01 - INFO - valuate on validation set:
# 2024-07-30 19:21:01 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:01 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:01,148] Trial 179 finished with value: 0.9385584592819214 and parameters: {'window_sizes': 3, 'num_of_epochs': 864, 'lr': 0.030445997045574682, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:21:01 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:01 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:01 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:01 - INFO - Train the model:
# 2024-07-30 19:21:06 - INFO - valuate on validation set:
# 2024-07-30 19:21:06 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:06 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:06,524] Trial 180 pruned.
# 2024-07-30 19:21:06 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:06 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:07 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:07 - INFO - Train the model:
# 2024-07-30 19:21:11 - INFO - valuate on validation set:
# 2024-07-30 19:21:11 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:11 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:11,489] Trial 181 pruned.
# 2024-07-30 19:21:11 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:11 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:12 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:12 - INFO - Train the model:
# 2024-07-30 19:21:16 - INFO - valuate on validation set:
# 2024-07-30 19:21:16 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:16 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:16,435] Trial 182 pruned.
# 2024-07-30 19:21:16 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:16 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:18 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:18 - INFO - Train the model:
# 2024-07-30 19:21:21 - INFO - valuate on validation set:
# 2024-07-30 19:21:21 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:21 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:21,841] Trial 183 pruned.
# 2024-07-30 19:21:21 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:21 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:22 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:22 - INFO - Train the model:
# 2024-07-30 19:21:29 - INFO - valuate on validation set:
# 2024-07-30 19:21:29 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:29 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:29,647] Trial 184 pruned.
# 2024-07-30 19:21:29 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:29 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:30 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:30 - INFO - Train the model:
# 2024-07-30 19:21:34 - INFO - valuate on validation set:
# 2024-07-30 19:21:34 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:34 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:34,693] Trial 185 pruned.
# 2024-07-30 19:21:34 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:34 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:34 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:34 - INFO - Train the model:
# 2024-07-30 19:21:36 - INFO - valuate on validation set:
# 2024-07-30 19:21:36 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:36 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:36,899] Trial 186 finished with value: 2967.977294921875 and parameters: {'window_sizes': 7, 'num_of_epochs': 335, 'lr': 0.07741020292372192, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:21:36 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:36 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:37 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:37 - INFO - Train the model:
# 2024-07-30 19:21:43 - INFO - valuate on validation set:
# 2024-07-30 19:21:43 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:43 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:43,075] Trial 187 finished with value: 1.8531570434570312 and parameters: {'window_sizes': 4, 'num_of_epochs': 864, 'lr': 0.024371145262687376, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:21:43 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:43 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:43 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:43 - INFO - Train the model:
# 2024-07-30 19:21:50 - INFO - valuate on validation set:
# 2024-07-30 19:21:50 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:50 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:50,718] Trial 188 pruned.
# 2024-07-30 19:21:50 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:50 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:52 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:52 - INFO - Train the model:
# 2024-07-30 19:21:56 - INFO - valuate on validation set:
# 2024-07-30 19:21:56 - INFO - Calculate reconstruction error:
# 2024-07-30 19:21:56 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:21:56,914] Trial 189 finished with value: 4.288800239562988 and parameters: {'window_sizes': 1, 'num_of_epochs': 844, 'lr': 0.045137836169624294, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:21:56 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:21:56 - INFO - Create samples with the specified window size:
# 2024-07-30 19:21:57 - INFO - Build the autoencoder model:
# 2024-07-30 19:21:57 - INFO - Train the model:
# 2024-07-30 19:22:03 - INFO - valuate on validation set:
# 2024-07-30 19:22:03 - INFO - Calculate reconstruction error:
# 2024-07-30 19:22:03 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:22:03,069] Trial 190 finished with value: 1.3865803480148315 and parameters: {'window_sizes': 6, 'num_of_epochs': 858, 'lr': 0.020160638670354693, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:22:03 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:22:03 - INFO - Create samples with the specified window size:
# 2024-07-30 19:22:03 - INFO - Build the autoencoder model:
# 2024-07-30 19:22:03 - INFO - Train the model:
# 2024-07-30 19:22:10 - INFO - valuate on validation set:
# 2024-07-30 19:22:10 - INFO - Calculate reconstruction error:
# 2024-07-30 19:22:10 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:22:10,399] Trial 191 pruned.
# 2024-07-30 19:22:10 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:22:10 - INFO - Create samples with the specified window size:
# 2024-07-30 19:22:10 - INFO - Build the autoencoder model:
# 2024-07-30 19:22:10 - INFO - Train the model:
# 2024-07-30 19:22:17 - INFO - valuate on validation set:
# 2024-07-30 19:22:17 - INFO - Calculate reconstruction error:
# 2024-07-30 19:22:17 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:22:17,751] Trial 192 finished with value: 0.9974220991134644 and parameters: {'window_sizes': 4, 'num_of_epochs': 869, 'lr': 0.02307491532763883, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:22:17 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:22:17 - INFO - Create samples with the specified window size:
# 2024-07-30 19:22:18 - INFO - Build the autoencoder model:
# 2024-07-30 19:22:18 - INFO - Train the model:
# 2024-07-30 19:22:24 - INFO - valuate on validation set:
# 2024-07-30 19:22:24 - INFO - Calculate reconstruction error:
# 2024-07-30 19:22:24 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:22:24,426] Trial 193 pruned.
# 2024-07-30 19:22:24 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:22:24 - INFO - Create samples with the specified window size:
# 2024-07-30 19:22:25 - INFO - Build the autoencoder model:
# 2024-07-30 19:22:25 - INFO - Train the model:
# 2024-07-30 19:22:32 - INFO - valuate on validation set:
# 2024-07-30 19:22:32 - INFO - Calculate reconstruction error:
# 2024-07-30 19:22:32 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:22:32,107] Trial 194 finished with value: 0.6020652651786804 and parameters: {'window_sizes': 3, 'num_of_epochs': 891, 'lr': 0.031779295243310246, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:22:32 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:22:32 - INFO - Create samples with the specified window size:
# 2024-07-30 19:22:32 - INFO - Build the autoencoder model:
# 2024-07-30 19:22:32 - INFO - Train the model:
# 2024-07-30 19:22:38 - INFO - valuate on validation set:
# 2024-07-30 19:22:38 - INFO - Calculate reconstruction error:
# 2024-07-30 19:22:38 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:22:38,711] Trial 195 finished with value: 4.720599174499512 and parameters: {'window_sizes': 3, 'num_of_epochs': 889, 'lr': 0.03264687082787487, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:22:38 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:22:38 - INFO - Create samples with the specified window size:
# 2024-07-30 19:22:39 - INFO - Build the autoencoder model:
# 2024-07-30 19:22:39 - INFO - Train the model:
# 2024-07-30 19:22:47 - INFO - valuate on validation set:
# 2024-07-30 19:22:47 - INFO - Calculate reconstruction error:
# 2024-07-30 19:22:47 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:22:47,863] Trial 196 pruned.
# 2024-07-30 19:22:47 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:22:47 - INFO - Create samples with the specified window size:
# 2024-07-30 19:22:49 - INFO - Build the autoencoder model:
# 2024-07-30 19:22:49 - INFO - Train the model:
# 2024-07-30 19:22:54 - INFO - valuate on validation set:
# 2024-07-30 19:22:54 - INFO - Calculate reconstruction error:
# 2024-07-30 19:22:54 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:22:54,336] Trial 197 pruned.
# 2024-07-30 19:22:54 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:22:54 - INFO - Create samples with the specified window size:
# 2024-07-30 19:22:54 - INFO - Build the autoencoder model:
# 2024-07-30 19:22:54 - INFO - Train the model:
# 2024-07-30 19:22:59 - INFO - valuate on validation set:
# 2024-07-30 19:22:59 - INFO - Calculate reconstruction error:
# 2024-07-30 19:22:59 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:22:59,158] Trial 198 finished with value: 1.5236116647720337 and parameters: {'window_sizes': 7, 'num_of_epochs': 863, 'lr': 0.028440902308679735, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.
# 2024-07-30 19:22:59 - INFO - Starting off new loop to (re)train the model:
# 2024-07-30 19:22:59 - INFO - Create samples with the specified window size:
# 2024-07-30 19:22:59 - INFO - Build the autoencoder model:
# 2024-07-30 19:22:59 - INFO - Train the model:
# 2024-07-30 19:23:05 - INFO - valuate on validation set:
# 2024-07-30 19:23:05 - INFO - Calculate reconstruction error:
# 2024-07-30 19:23:05 - INFO - Calculate the mean reconstruction error:
# [I 2024-07-30 19:23:05,060] Trial 199 finished with value: 0.7793483138084412 and parameters: {'window_sizes': 4, 'num_of_epochs': 889, 'lr': 0.02148830604901321, 'num_of_layers': 1}. Best is trial 173 with value: 0.568994402885437.

# %% [markdown]
# ### checking the outcomes

# %%
# evauation
pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Study statistics:
#   Number of finished trials:  200
#   Number of pruned trials:  33
#   Number of complete trials:  167
# Best trial:
#   Value:  0.568994402885437
#   Params:
#     window_sizes: 3
#     num_of_epochs: 861
#     lr: 0.03777256269175889
#     num_of_layers: 1

# %%
best_window_size = trial.params['window_sizes']
best_num_of_epochs = trial.params['num_of_epochs']
best_learning_rate = trial.params['lr']
best_num_of_layers = trial.params["num_of_layers"]

# %% [markdown]
# ### train the algorithm with the best window

# %%
(
    trained_model,
    reconstructed_data_training,
    avg_reconstruction_error_training,
    std_reconstruction_error_training,
    upper_threshold_training,
) = train_the_model_with_optimized_hyperparameters(
    df=data_to_train,
    num_of_layers=best_num_of_layers,
    window_size=best_window_size,
    variable_of_interest=variable_of_interest,
    num_epochs=best_num_of_epochs,
    learning_rate=best_learning_rate,
    tolerance_for_anomaly=tolerance_for_anomaly,
)
# Out:
# 2024-07-30 19:23:05 - INFO - Inicializing the training process with the best selected windows size: 3
# 2024-07-30 19:23:05 - INFO - building the autoencoder models
# 2024-07-30 19:23:05 - INFO - training the model:
# 2024-07-30 19:23:05 - INFO - Epoch 1, Loss: 4457.53857421875
# 2024-07-30 19:23:06 - INFO - Epoch 11, Loss: 687.0089111328125
# 2024-07-30 19:23:06 - INFO - Epoch 21, Loss: 231.0187530517578
# 2024-07-30 19:23:06 - INFO - Epoch 31, Loss: 74.55015563964844
# 2024-07-30 19:23:06 - INFO - Epoch 41, Loss: 45.93355941772461
# 2024-07-30 19:23:06 - INFO - Epoch 51, Loss: 32.90602493286133
# 2024-07-30 19:23:06 - INFO - Epoch 61, Loss: 28.202293395996094
# 2024-07-30 19:23:06 - INFO - Epoch 71, Loss: 26.188955307006836
# 2024-07-30 19:23:06 - INFO - Epoch 81, Loss: 24.795394897460938
# 2024-07-30 19:23:06 - INFO - Epoch 91, Loss: 23.860828399658203
# 2024-07-30 19:23:06 - INFO - Epoch 101, Loss: 22.850914001464844
# 2024-07-30 19:23:06 - INFO - Epoch 111, Loss: 21.722814559936523
# 2024-07-30 19:23:06 - INFO - Epoch 121, Loss: 20.36432647705078
# 2024-07-30 19:23:06 - INFO - Epoch 131, Loss: 18.772167205810547
# 2024-07-30 19:23:06 - INFO - Epoch 141, Loss: 16.97303009033203
# 2024-07-30 19:23:06 - INFO - Epoch 151, Loss: 15.090017318725586
# 2024-07-30 19:23:06 - INFO - Epoch 161, Loss: 13.154918670654297
# 2024-07-30 19:23:06 - INFO - Epoch 171, Loss: 11.307580947875977
# 2024-07-30 19:23:07 - INFO - Epoch 181, Loss: 9.700745582580566
# 2024-07-30 19:23:07 - INFO - Epoch 191, Loss: 8.373835563659668
# 2024-07-30 19:23:07 - INFO - Epoch 201, Loss: 7.355946063995361
# 2024-07-30 19:23:07 - INFO - Epoch 211, Loss: 6.595420837402344
# 2024-07-30 19:23:07 - INFO - Epoch 221, Loss: 6.021867275238037
# 2024-07-30 19:23:07 - INFO - Epoch 231, Loss: 5.568572998046875
# 2024-07-30 19:23:07 - INFO - Epoch 241, Loss: 5.178714275360107
# 2024-07-30 19:23:07 - INFO - Epoch 251, Loss: 5.125528812408447
# 2024-07-30 19:23:07 - INFO - Epoch 261, Loss: 4.451157093048096
# 2024-07-30 19:23:07 - INFO - Epoch 271, Loss: 4.089504718780518
# 2024-07-30 19:23:07 - INFO - Epoch 281, Loss: 3.6632795333862305
# 2024-07-30 19:23:07 - INFO - Epoch 291, Loss: 2.979729652404785
# 2024-07-30 19:23:07 - INFO - Epoch 301, Loss: 2.468644142150879
# 2024-07-30 19:23:07 - INFO - Epoch 311, Loss: 2.2897374629974365
# 2024-07-30 19:23:07 - INFO - Epoch 321, Loss: 2.1597819328308105
# 2024-07-30 19:23:07 - INFO - Epoch 331, Loss: 2.076632022857666
# 2024-07-30 19:23:07 - INFO - Epoch 341, Loss: 2.0096447467803955
# 2024-07-30 19:23:07 - INFO - Epoch 351, Loss: 1.956782579421997
# 2024-07-30 19:23:08 - INFO - Epoch 361, Loss: 1.9127475023269653
# 2024-07-30 19:23:08 - INFO - Epoch 371, Loss: 1.8758292198181152
# 2024-07-30 19:23:08 - INFO - Epoch 381, Loss: 1.8441944122314453
# 2024-07-30 19:23:08 - INFO - Epoch 391, Loss: 1.8167108297348022
# 2024-07-30 19:23:08 - INFO - Epoch 401, Loss: 1.792487382888794
# 2024-07-30 19:23:08 - INFO - Epoch 411, Loss: 1.7709600925445557
# 2024-07-30 19:23:08 - INFO - Epoch 421, Loss: 1.7968099117279053
# 2024-07-30 19:23:08 - INFO - Epoch 431, Loss: 1.8044344186782837
# 2024-07-30 19:23:08 - INFO - Epoch 441, Loss: 1.7353007793426514
# 2024-07-30 19:23:08 - INFO - Epoch 451, Loss: 1.7089751958847046
# 2024-07-30 19:23:08 - INFO - Epoch 461, Loss: 1.6926943063735962
# 2024-07-30 19:23:08 - INFO - Epoch 471, Loss: 1.676782250404358
# 2024-07-30 19:23:08 - INFO - Epoch 481, Loss: 1.662927508354187
# 2024-07-30 19:23:08 - INFO - Epoch 491, Loss: 1.6508454084396362
# 2024-07-30 19:23:08 - INFO - Epoch 501, Loss: 1.6389821767807007
# 2024-07-30 19:23:08 - INFO - Epoch 511, Loss: 1.6273901462554932
# 2024-07-30 19:23:08 - INFO - Epoch 521, Loss: 1.6160115003585815
# 2024-07-30 19:23:08 - INFO - Epoch 531, Loss: 1.6047149896621704
# 2024-07-30 19:23:08 - INFO - Epoch 541, Loss: 1.5934122800827026
# 2024-07-30 19:23:09 - INFO - Epoch 551, Loss: 1.5820211172103882
# 2024-07-30 19:23:09 - INFO - Epoch 561, Loss: 1.5704894065856934
# 2024-07-30 19:23:09 - INFO - Epoch 571, Loss: 1.5587462186813354
# 2024-07-30 19:23:09 - INFO - Epoch 581, Loss: 1.546726942062378
# 2024-07-30 19:23:09 - INFO - Epoch 591, Loss: 1.5428857803344727
# 2024-07-30 19:23:09 - INFO - Epoch 601, Loss: 4.214897632598877
# 2024-07-30 19:23:09 - INFO - Epoch 611, Loss: 2.103923797607422
# 2024-07-30 19:23:09 - INFO - Epoch 621, Loss: 1.7464101314544678
# 2024-07-30 19:23:09 - INFO - Epoch 631, Loss: 1.569050669670105
# 2024-07-30 19:23:09 - INFO - Epoch 641, Loss: 1.4919872283935547
# 2024-07-30 19:23:09 - INFO - Epoch 651, Loss: 1.4601064920425415
# 2024-07-30 19:23:09 - INFO - Epoch 661, Loss: 1.4401500225067139
# 2024-07-30 19:23:09 - INFO - Epoch 671, Loss: 1.419305443763733
# 2024-07-30 19:23:09 - INFO - Epoch 681, Loss: 1.400089979171753
# 2024-07-30 19:23:09 - INFO - Epoch 691, Loss: 1.3811410665512085
# 2024-07-30 19:23:09 - INFO - Epoch 701, Loss: 1.3610785007476807
# 2024-07-30 19:23:10 - INFO - Epoch 711, Loss: 1.340225338935852
# 2024-07-30 19:23:10 - INFO - Epoch 721, Loss: 1.31852388381958
# 2024-07-30 19:23:10 - INFO - Epoch 731, Loss: 1.2959243059158325
# 2024-07-30 19:23:10 - INFO - Epoch 741, Loss: 1.2724609375
# 2024-07-30 19:23:10 - INFO - Epoch 751, Loss: 1.2484596967697144
# 2024-07-30 19:23:10 - INFO - Epoch 761, Loss: 1.2672735452651978
# 2024-07-30 19:23:10 - INFO - Epoch 771, Loss: 6.196774482727051
# 2024-07-30 19:23:10 - INFO - Epoch 781, Loss: 2.2196805477142334
# 2024-07-30 19:23:10 - INFO - Epoch 791, Loss: 1.36724054813385
# 2024-07-30 19:23:10 - INFO - Epoch 801, Loss: 1.1798644065856934
# 2024-07-30 19:23:10 - INFO - Epoch 811, Loss: 1.124752163887024
# 2024-07-30 19:23:10 - INFO - Epoch 821, Loss: 1.0658929347991943
# 2024-07-30 19:23:10 - INFO - Epoch 831, Loss: 1.0393155813217163
# 2024-07-30 19:23:10 - INFO - Epoch 841, Loss: 1.0043898820877075
# 2024-07-30 19:23:11 - INFO - Epoch 851, Loss: 0.9745833873748779
# 2024-07-30 19:23:11 - INFO - Epoch 861, Loss: 0.9457315802574158
# 2024-07-30 19:23:11 - INFO - calculate the reconstruction error:
# 2024-07-30 19:23:11 - INFO - Set a threshold for anomaly based on the average and standard deviation
# 2024-07-30 19:23:11 - INFO - Average Reconstruction Error for RO1_permeate_conductivity: 1.0954632620516154
# 2024-07-30 19:23:11 - INFO - Standard Deviation of Reconstruction Error for RO1_permeate_conductivity: 22.33208582783377
# 2024-07-30 19:23:11 - INFO - upper threshold for RO1_permeate_conductivity: 425.40509399089325

# %% [markdown]
# ### saving the model

# %%
base_path = f"{path_to_save_the_outcomes}/tmp/trained_model/{variable_of_interest}/{timestamp_for_this_experiment}"

additional_info = {
    "model_type": "Autoencoder",
    "target_sensor": f"{variable_of_interest}",
    "data_used_to_train_the_model": f"from {start_timestamp_for_training} to {end_timestamp_for_training}",
    "path_where_it_is_saved": f"tmp/normal_data_to_train_the_model/{variable_of_interest}/{timestamp_for_this_experiment}/training_data/",
    "average_reconstruction_error_for_this_model_in_training": trial.value,
    "best_window_size": trial.params['window_sizes'],
    "best_number_of_epoches": trial.params['num_of_epochs'],
    "best_learinng_rate": trial.params['lr'],
    "threshold_for_the_reconstruction_error": upper_threshold_training,
}
save_model(trained_model, base_path, additional_info)

# %% [markdown]
# ### test the algorithm in real data

# %%
(
    reconstructed_df_test,
    anomalies_df_test,
    num_detected_anomalies_test,
) = detect_anomalies_using_trained_model(
    combined_df_with_all_trains_info,
    trained_model,
    best_window_size,
    variable_of_interest,
    upper_threshold_training,
)
# Out:
# 2024-07-30 19:23:11 - INFO - inicializing the anomaly detection process with the trained model
# 2024-07-30 19:23:25 - INFO - calculating the reconstruction error
# 2024-07-30 19:23:25 - INFO - total points of data to be analyzed for the variable of interest: 892800
# 2024-07-30 19:23:25 - INFO - total of anomalyes found: 1779
# 2024-07-30 19:23:25 - INFO - percentage of anomalies in this sensor: 0.19926075268817206 %

# %% [markdown]
# ### total of anomalies

# %%
anomalies_df_test.head()
# Out:
#                            RO1_permeate_flow  RO1_silica_saturation_index  \
# 2024-01-02 09:39:27+00:00           2.530549                    -2.026058
# 2024-01-02 09:39:30+00:00           2.599676                    -1.728413
# 2024-01-02 09:39:33+00:00           2.934308                    -1.834590
# 2024-01-02 17:03:09+00:00          20.678276                    -2.507674
# 2024-01-02 17:03:15+00:00          21.859472                    -1.462742
#
#                            RO1_calcium_fluoride_saturation_index  \
# 2024-01-02 09:39:27+00:00                             -13.376057
# 2024-01-02 09:39:30+00:00                             -13.534751
# 2024-01-02 09:39:33+00:00                             -13.342348
# 2024-01-02 17:03:09+00:00                              -8.263836
# 2024-01-02 17:03:15+00:00                              -8.307275
#
#                            RO1_feed_flow  RO1_permeate_conductivity  \
# 2024-01-02 09:39:27+00:00      -2.041688                  81.164505
# 2024-01-02 09:39:30+00:00      -1.808773                  81.113274
# 2024-01-02 09:39:33+00:00      -1.618228                  80.545891
# 2024-01-02 17:03:09+00:00      24.669945                 146.228760
# 2024-01-02 17:03:15+00:00      24.419050                 142.714447
#
#                            feed_ph_1  feed_silica  feed_calcium  \
# 2024-01-02 09:39:27+00:00   6.354158     7.843384      0.275684
# 2024-01-02 09:39:30+00:00   6.474095     7.808065      0.160919
# 2024-01-02 09:39:33+00:00   6.754933     8.367941     -0.089654
# 2024-01-02 17:03:09+00:00   5.950719     6.598751      0.737161
# 2024-01-02 17:03:15+00:00   8.184243     9.679292     -1.517392
#
#                            feed_temperature  feed_orp_1  \
# 2024-01-02 09:39:27+00:00         29.515610  162.629257
# 2024-01-02 09:39:30+00:00         29.275845  162.614960
# 2024-01-02 09:39:33+00:00         29.186785  162.852966
# 2024-01-02 17:03:09+00:00         34.503563  185.094040
# 2024-01-02 17:03:15+00:00         32.317673  186.395874
#
#                            RO1_permeate_conductivity_error
# 2024-01-02 09:39:27+00:00                      1490.583996
# 2024-01-02 09:39:30+00:00                      1074.809253
# 2024-01-02 09:39:33+00:00                      5663.406715
# 2024-01-02 17:03:09+00:00                       725.560258
# 2024-01-02 17:03:15+00:00                      2187.209624

# %% [markdown]
# # Step 4: evaluate the outcomes - plotting the results

# %% [markdown]
# ### visualize the reconstruction errors and the real plot with the anomalies

# %%
# Assuming you have the DataFrame 'reconstructed_data_training' and the error statistics calculated
plot = reconstructed_error_analysis_plot_with_holoviews(
    error_df=reconstructed_df_test,
    variable_of_interest=variable_of_interest,
    avg_error=avg_reconstruction_error_training,
    upper_threshold=upper_threshold_training,
    save_plot=True,
    name_of_the_plot="ro1_real_data",
    save_path=f"{path_to_save_the_outcomes}/tmp/outcomes_from_the_model/{variable_of_interest}/{timestamp_for_this_experiment}/reconstruction_error_analysis/",
)

# %% [markdown]
# ### combine all data and the sppoted anomalies - plots for final analyses

# %%
combine_and_slice_plost_to_support_final_analyses(
    combined_df_with_all_trains_info=combined_df_with_all_trains_info,
    anomalies_df_test=anomalies_df_test,
    variable_of_interest=variable_of_interest,
    path_to_save_the_outcomes=path_to_save_the_outcomes,
    timestamp_for_this_experiment=timestamp_for_this_experiment,
    start_timestamp=start_timestamp,
    end_timestamp=end_timestamp,
    number_of_chunks=number_of_chunks,
)
